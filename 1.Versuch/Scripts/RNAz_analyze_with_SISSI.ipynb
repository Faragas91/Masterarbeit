# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, auc, accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import metrics

# %%
df_sissi = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/sissi.xlsx"))
df_sissiz_mono = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/sissiz_mono.xlsx"))
df_sissiz_di = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/sissiz_di.xlsx"))
df_multiperm_mono = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/multiperm_mono.xlsx"))
df_multiperm_di = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/multiperm_di.xlsx"))
df_aln_shuffle = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/RNAz_Data_di_Excel/alifoldz.xlsx"))

# %%
# df_sissi = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/sissi.xlsx"))
# df_sissiz_mono = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/sissiz_mono.xlsx"))
# df_sissiz_di = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/sissiz_di.xlsx"))
# df_multiperm_mono = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/multiperm_mono.xlsx"))
# df_multiperm_di = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/multiperm_di.xlsx"))
# df_aln_shuffle = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/RNAz_Data_di_Excel/alifoldz.xlsx"))

# %%
new_df_sissi = df_sissi.drop(['Sequences', 'Columns'], axis=1)
new_df_sissi.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   88.56          0.33271      0.49297
# 1                   87.03          0.37237      0.47679
# 2                   88.15          0.34519      0.50339
# 3                   88.53          0.33514      0.45837
# 4                   88.63          0.33170      0.51272
# 5                   87.80          0.35132      0.49504
# 6                   87.54          0.36054      0.46915
# 7                   85.90          0.40009      0.47768
# 8                   87.78          0.35122      0.44766
# 9                   88.20          0.34545      0.47778
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -158.98         -89.35               -85.71
# 1                   -143.04         -88.69               -83.58
# 2                   -175.00        -109.84              -105.98
# 3                   -142.09         -79.41               -75.35
# 4                   -166.38        -109.89              -105.98
# 5                   -156.16        -100.00               -95.11
# 6                   -151.43         -85.51               -81.01
# 7                   -157.45         -82.41               -77.57
# 8                   -141.66         -80.46               -75.97
# 9                   -157.35        -106.12               -99.98
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                    -3.63               2.35        -48.40
# 1                    -5.12               2.40        -44.32
# 2                    -3.86               2.43        -50.59
# 3                    -4.06               2.37        -55.46
# 4                    -3.91               2.24        -45.03
# 5                    -4.88               2.44        -45.29
# 6                    -4.50               2.49        -51.48
# 7                    -4.84               2.42        -52.21
# 8                    -4.50               2.28        -62.70
# 9                    -6.14               2.48        -50.26
#
#    Structure conservation index  SVM decision value  \
# 0                          0.56                3.43
# 1                          0.62                3.19
# 2                          0.63                3.15
# 3                          0.56                3.43
# 4                          0.66                3.01
# 5                          0.64                3.10
# 6                          0.56                3.44
# 7                          0.52                3.58
# 8                          0.57                3.40
# 9                          0.67                2.95
#
#    SVM RNA-class probability                      File
# 0                   0.998643  pos_sample_output_55.txt
# 1                   0.997839  pos_sample_output_89.txt
# 2                   0.997668  pos_sample_output_72.txt
# 3                   0.998645  pos_sample_output_20.txt
# 4                   0.996937  pos_sample_output_97.txt
# 5                   0.997433  pos_sample_output_37.txt
# 6                   0.998660  pos_sample_output_87.txt
# 7                   0.998978  pos_sample_output_12.txt
# 8                   0.998560  pos_sample_output_68.txt
# 9                   0.996570  pos_sample_output_11.txt

# %%
new_df_sissi[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy  G+C content  \
# count              100.000000       100.000000   100.000000
# mean                87.445100         0.361246     0.488293
# std                  0.756851         0.017965     0.026755
# min                 84.960000         0.326170     0.421830
# 25%                 86.980000         0.348790     0.469832
# 50%                 87.505000         0.360565     0.487960
# 75%                 87.977500         0.372213     0.507380
# max                 88.900000         0.419530     0.546100
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count                100.000000     100.000000           100.000000
# mean                -156.546600     -89.324900           -84.676400
# std                   10.126071      12.603013            12.269277
# min                 -176.760000    -129.810000          -124.680000
# 25%                 -162.980000     -97.665000           -92.587500
# 50%                 -157.570000     -88.920000           -84.910000
# 75%                 -148.492500     -80.692500           -76.052500
# max                 -131.740000     -56.810000           -53.500000
#
#        Covariance contribution  Combinations/Pair  Mean z-score  \
# count               100.000000         100.000000    100.000000
# mean                 -4.648700           2.416200    -49.381700
# std                   1.030818           0.081213      6.743834
# min                  -7.340000           2.110000    -73.220000
# 25%                  -5.152500           2.367500    -52.232500
# 50%                  -4.650000           2.420000    -47.415000
# 75%                  -3.900000           2.472500    -44.637500
# max                  -1.970000           2.590000    -39.750000
#
#        Structure conservation index  SVM decision value  \
# count                    100.000000          100.000000
# mean                       0.569700            3.365300
# std                        0.063619            0.241797
# min                        0.390000            2.470000
# 25%                        0.530000            3.240000
# 50%                        0.570000            3.400000
# 75%                        0.610000            3.532500
# max                        0.750000            3.770000
#
#        SVM RNA-class probability
# count                 100.000000
# mean                    0.998253
# std                     0.001126
# min                     0.991373
# 25%                     0.998037
# 50%                     0.998568
# 75%                     0.998891
# max                     0.999289

# %%
new_df_sissiz_mono = df_sissiz_mono.drop(['Sequences', 'Columns'], axis=1)
new_df_sissiz_mono.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   87.36          0.37518      0.51269
# 1                   87.92          0.36275      0.43286
# 2                   86.91          0.39075      0.47666
# 3                   84.13          0.45984      0.52967
# 4                   86.83          0.38939      0.45898
# 5                   86.49          0.39543      0.54115
# 6                   86.29          0.40771      0.46240
# 7                   87.46          0.37056      0.48130
# 8                   86.96          0.38667      0.49207
# 9                   85.33          0.42585      0.47145
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -136.55         -10.02               -10.13
# 1                   -107.94          -4.15                -4.12
# 2                   -115.96          -7.61                -7.62
# 3                   -141.22         -11.09               -10.90
# 4                   -118.85          -4.08                -3.94
# 5                   -144.52         -15.89               -15.93
# 6                   -117.68          -5.90                -6.00
# 7                   -119.89         -18.99               -18.95
# 8                   -132.15          -8.10                -8.06
# 9                   -108.56          -5.19                -5.02
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                     0.10               1.52        -29.77
# 1                    -0.02               1.83        -41.30
# 2                     0.02               1.53        -28.73
# 3                    -0.19               1.60        -30.88
# 4                    -0.14               1.84        -39.99
# 5                     0.04               1.50        -32.28
# 6                     0.10               1.54        -36.09
# 7                    -0.04               1.53        -29.58
# 8                    -0.04               1.52        -34.36
# 9                    -0.16               1.69        -25.77
#
#    Structure conservation index  SVM decision value  \
# 0                          0.07                2.71
# 1                          0.04                2.51
# 2                          0.07                2.74
# 3                          0.08                2.94
# 4                          0.03                2.50
# 5                          0.11                2.97
# 6                          0.05                2.66
# 7                          0.16                3.17
# 8                          0.06                2.68
# 9                          0.05                2.70
#
#    SVM RNA-class probability                                      File
# 0                   0.994587  neg_sample_SISSIz_mono_output_60_175.txt
# 1                   0.992039  neg_sample_SISSIz_mono_output_20_322.txt
# 2                   0.994891  neg_sample_SISSIz_mono_output_88_522.txt
# 3                   0.996513  neg_sample_SISSIz_mono_output_23_838.txt
# 4                   0.991894  neg_sample_SISSIz_mono_output_62_322.txt
# 5                   0.996715  neg_sample_SISSIz_mono_output_65_491.txt
# 6                   0.994007  neg_sample_SISSIz_mono_output_38_840.txt
# 7                   0.997768  neg_sample_SISSIz_mono_output_33_485.txt
# 8                   0.994201  neg_sample_SISSIz_mono_output_16_182.txt
# 9                   0.994421  neg_sample_SISSIz_mono_output_47_686.txt

# %%
new_df_sissiz_mono[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy    G+C content  \
# count           100000.000000    100000.000000  100000.000000
# mean                86.583645         0.395997       0.488262
# std                  0.904675         0.022921       0.035077
# min                 82.760000         0.328120       0.350310
# 25%                 85.990000         0.379720       0.464670
# 50%                 86.630000         0.394930       0.488940
# 75%                 87.220000         0.410950       0.512150
# max                 89.260000         0.496620       0.611770
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count             100000.000000  100000.000000        100000.000000
# mean                -126.134666      -8.969149            -9.000053
# std                   11.694756       4.271175             4.285494
# min                 -175.700000     -28.990000           -28.960000
# 25%                 -133.980000     -11.620000           -11.680000
# 50%                 -126.070000      -8.590000            -8.620000
# 75%                 -118.200000      -5.850000            -5.880000
# max                  -82.370000       0.000000             0.060000
#
#        Covariance contribution  Combinations/Pair   Mean z-score  \
# count            100000.000000      100000.000000  100000.000000
# mean                  0.030955           1.573494     -33.062698
# std                   0.253405           0.176617       5.399544
# min                  -1.020000           0.000000     -54.200000
# 25%                  -0.080000           1.470000     -35.680000
# 50%                   0.020000           1.570000     -31.910000
# 75%                   0.100000           1.680000     -29.340000
# max                   3.100000           2.250000      -1.550000
#
#        Structure conservation index  SVM decision value  \
# count                 100000.000000       100000.000000
# mean                       0.070079            2.747887
# std                        0.030967            0.177123
# min                       -0.000000           -5.750000
# 25%                        0.050000            2.630000
# 50%                        0.070000            2.740000
# 75%                        0.090000            2.860000
# max                        0.200000            3.390000
#
#        SVM RNA-class probability
# count              100000.000000
# mean                    0.994645
# std                     0.007878
# min                     0.000015
# 25%                     0.993706
# 50%                     0.994891
# 75%                     0.995906
# max                     0.998523

# %%
new_df_sissiz_di = df_sissiz_di.drop(['Sequences', 'Columns'], axis=1)
new_df_sissiz_di.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   86.85          0.38935      0.49703
# 1                   88.05          0.35980      0.53501
# 2                   84.93          0.43806      0.49194
# 3                   86.67          0.38942      0.47669
# 4                   87.11          0.37974      0.53293
# 5                   86.11          0.41100      0.48254
# 6                   87.03          0.38615      0.52363
# 7                   85.12          0.42915      0.43823
# 8                   85.72          0.41673      0.46592
# 9                   85.76          0.41956      0.48760
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -133.62         -13.98               -13.73
# 1                   -142.31         -13.16               -13.35
# 2                   -131.85         -11.54               -11.93
# 3                   -118.53          -7.35                -7.40
# 4                   -141.75         -16.40               -16.12
# 5                   -122.43         -13.53               -13.69
# 6                   -144.79         -18.36               -18.48
# 7                   -116.63          -7.75                -7.66
# 8                   -124.10         -15.30               -15.34
# 9                   -127.29          -2.35                -2.52
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                    -0.25               2.07        -32.56
# 1                     0.19               1.50        -31.36
# 2                     0.38               1.77        -33.58
# 3                     0.05               1.56        -30.10
# 4                    -0.28               1.58        -31.31
# 5                     0.16               1.66        -31.44
# 6                     0.12               1.77        -32.63
# 7                    -0.10               1.59        -46.96
# 8                     0.04               1.58        -37.66
# 9                     0.17               1.53        -33.40
#
#    Structure conservation index  SVM decision value  \
# 0                          0.10                2.91
# 1                          0.09                2.80
# 2                          0.09                2.95
# 3                          0.06                2.68
# 4                          0.12                2.99
# 5                          0.11                3.00
# 6                          0.13                3.06
# 7                          0.07                2.82
# 8                          0.12                3.07
# 9                          0.02                2.50
#
#    SVM RNA-class probability                                    File
# 0                   0.996278   neg_sample_SISSIz_di_output_7_471.txt
# 1                   0.995395   neg_sample_SISSIz_di_output_69_45.txt
# 2                   0.996571  neg_sample_SISSIz_di_output_76_235.txt
# 3                   0.994260  neg_sample_SISSIz_di_output_48_902.txt
# 4                   0.996854   neg_sample_SISSIz_di_output_9_815.txt
# 5                   0.996901  neg_sample_SISSIz_di_output_29_568.txt
# 6                   0.997212  neg_sample_SISSIz_di_output_91_913.txt
# 7                   0.995596   neg_sample_SISSIz_di_output_1_229.txt
# 8                   0.997255  neg_sample_SISSIz_di_output_92_765.txt
# 9                   0.991891  neg_sample_SISSIz_di_output_73_895.txt

# %%
new_df_sissiz_di[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy    G+C content  \
# count           100000.000000    100000.000000  100000.000000
# mean                86.489937         0.396897       0.489271
# std                  0.909399         0.022964       0.035767
# min                 82.670000         0.327300       0.354270
# 25%                 85.900000         0.380610       0.465090
# 50%                 86.530000         0.395900       0.489640
# 75%                 87.140000         0.411740       0.513620
# max                 89.370000         0.498870       0.617690
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count             100000.000000  100000.000000        100000.000000
# mean                -127.909001     -10.406722           -10.429899
# std                   12.185140       4.568141             4.576527
# min                 -176.750000     -33.090000           -34.800000
# 25%                 -135.940000     -13.260000           -13.270000
# 50%                 -127.730000      -9.990000           -10.015000
# 75%                 -119.530000      -7.110000            -7.150000
# max                  -81.330000       0.000000             0.000000
#
#        Covariance contribution  Combinations/Pair   Mean z-score  \
# count            100000.000000      100000.000000  100000.000000
# mean                  0.023176           1.571912     -33.766457
# std                   0.239987           0.154548       5.327307
# min                  -0.960000           0.000000     -55.000000
# 25%                  -0.080000           1.470000     -36.340000
# 50%                   0.020000           1.570000     -32.620000
# 75%                   0.110000           1.670000     -30.090000
# max                   2.840000           2.570000      -4.370000
#
#        Structure conservation index  SVM decision value  \
# count                 100000.000000       100000.000000
# mean                       0.080605            2.808834
# std                        0.033072            0.173061
# min                        0.000000            0.750000
# 25%                        0.060000            2.690000
# 50%                        0.080000            2.800000
# 75%                        0.100000            2.920000
# max                        0.240000            3.490000
#
#        SVM RNA-class probability
# count              100000.000000
# mean                    0.995254
# std                     0.002037
# min                     0.806883
# 25%                     0.994318
# 50%                     0.995452
# 75%                     0.996396
# max                     0.998779

# %%
new_df_multiperm_mono = df_multiperm_mono.drop(['Sequences', 'Columns'], axis=1)
new_df_multiperm_mono.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   86.90          0.37424      0.45102
# 1                   84.96          0.41953      0.51810
# 2                   86.42          0.38677      0.50003
# 3                   88.15          0.34519      0.50339
# 4                   87.30          0.36575      0.46851
# 5                   87.65          0.36130      0.48686
# 6                   87.26          0.36244      0.50246
# 7                   88.40          0.34376      0.45671
# 8                   86.98          0.37106      0.50774
# 9                   86.98          0.37106      0.50774
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -117.45         -28.05               -26.11
# 1                   -138.85         -33.47               -31.93
# 2                   -134.83         -32.13               -29.33
# 3                   -135.98         -40.22               -37.64
# 4                   -120.46         -28.17               -26.07
# 5                   -120.49         -23.78               -23.05
# 6                   -137.35         -31.03               -29.79
# 7                   -122.89         -24.09               -23.18
# 8                   -131.52         -36.26               -33.85
# 9                   -137.49         -34.90               -32.49
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                    -1.94               2.16        -43.84
# 1                    -1.54               2.17        -30.34
# 2                    -2.80               2.15        -32.92
# 3                    -2.58               2.19        -31.07
# 4                    -2.10               2.13        -33.60
# 5                    -0.74               2.00        -29.47
# 6                    -1.24               2.11        -33.23
# 7                    -0.91               2.13        -43.18
# 8                    -2.42               2.18        -28.11
# 9                    -2.41               2.09        -31.08
#
#    Structure conservation index  SVM decision value  \
# 0                          0.24                3.49
# 1                          0.24                3.57
# 2                          0.24                3.51
# 3                          0.30                3.61
# 4                          0.23                3.45
# 5                          0.20                3.33
# 6                          0.23                3.44
# 7                          0.20                3.30
# 8                          0.28                3.60
# 9                          0.25                3.52
#
#    SVM RNA-class probability                                         File
# 0                   0.998797  neg_sample_MULTIPERM_mono_output_39_770.txt
# 1                   0.998959  neg_sample_MULTIPERM_mono_output_23_824.txt
# 2                   0.998844   neg_sample_MULTIPERM_mono_output_2_971.txt
# 3                   0.999035   neg_sample_MULTIPERM_mono_output_72_12.txt
# 4                   0.998682  neg_sample_MULTIPERM_mono_output_29_441.txt
# 5                   0.998345  neg_sample_MULTIPERM_mono_output_34_847.txt
# 6                   0.998668   neg_sample_MULTIPERM_mono_output_5_384.txt
# 7                   0.998245  neg_sample_MULTIPERM_mono_output_58_446.txt
# 8                   0.999024  neg_sample_MULTIPERM_mono_output_41_976.txt
# 9                   0.998856  neg_sample_MULTIPERM_mono_output_41_304.txt

# %%
new_df_multiperm_mono[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy    G+C content  \
# count           100000.000000    100000.000000  100000.000000
# mean                87.445100         0.361246       0.488293
# std                  0.753061         0.017875       0.026621
# min                 84.960000         0.326170       0.421830
# 25%                 86.980000         0.348790       0.469832
# 50%                 87.505000         0.360565       0.487960
# 75%                 87.977500         0.372213       0.507380
# max                 88.900000         0.419530       0.546100
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count             100000.000000  100000.000000        100000.000000
# mean                -128.426400     -29.865833           -28.475634
# std                    9.106133       7.007184             6.861303
# min                 -163.820000     -60.630000           -59.710000
# 25%                 -134.700000     -34.730000           -33.240000
# 50%                 -128.570000     -29.600000           -28.180000
# 75%                 -122.100000     -24.710000           -23.430000
# max                  -97.820000      -8.130000            -7.280000
#
#        Covariance contribution  Combinations/Pair   Mean z-score  \
# count            100000.000000      100000.000000  100000.000000
# mean                 -1.390208           2.089866     -33.925208
# std                   0.528018           0.075817       4.536665
# min                  -3.860000           1.710000     -54.450000
# 25%                  -1.710000           2.040000     -35.750000
# 50%                  -1.380000           2.090000     -32.880000
# 75%                  -1.080000           2.140000     -30.800000
# max                   2.830000           2.490000     -23.480000
#
#        Structure conservation index  SVM decision value  \
# count                 100000.000000       100000.000000
# mean                       0.231267            3.424215
# std                        0.046243            0.146789
# min                        0.070000            2.720000
# 25%                        0.200000            3.330000
# 50%                        0.230000            3.440000
# 75%                        0.260000            3.530000
# max                        0.450000            3.750000
#
#        SVM RNA-class probability
# count              100000.000000
# mean                    0.998566
# std                     0.000444
# min                     0.994699
# 25%                     0.998355
# 50%                     0.998665
# 75%                     0.998887
# max                     0.999260

# %%
new_df_multiperm_di = df_multiperm_di.drop(['Sequences', 'Columns'], axis=1)
new_df_multiperm_di.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   87.97          0.35164      0.46796
# 1                   87.23          0.36508      0.49249
# 2                   87.23          0.36508      0.49249
# 3                   87.59          0.35746      0.49412
# 4                   88.05          0.34423      0.48891
# 5                   86.56          0.37724      0.51915
# 6                   87.68          0.35528      0.46988
# 7                   86.30          0.38886      0.43283
# 8                   87.82          0.34907      0.51304
# 9                   87.61          0.35554      0.50441
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -118.68         -25.67               -24.42
# 1                   -131.86         -32.51               -30.88
# 2                   -131.18         -31.11               -29.79
# 3                   -130.00         -30.06               -28.78
# 4                   -126.55         -40.96               -39.96
# 5                   -136.08         -37.56               -35.24
# 6                   -125.30         -28.74               -27.63
# 7                   -114.97         -20.77               -19.66
# 8                   -137.88         -37.74               -35.76
# 9                   -134.56         -44.10               -41.60
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                    -1.25               2.15        -34.09
# 1                    -1.63               2.07        -33.46
# 2                    -1.32               2.11        -33.11
# 3                    -1.28               2.08        -31.64
# 4                    -1.00               2.00        -31.55
# 5                    -2.32               2.09        -29.01
# 6                    -1.11               2.08        -37.27
# 7                    -1.11               2.16        -45.35
# 8                    -1.98               2.06        -30.55
# 9                    -2.50               2.09        -30.98
#
#    Structure conservation index  SVM decision value  \
# 0                          0.22                3.39
# 1                          0.25                3.51
# 2                          0.24                3.48
# 3                          0.23                3.43
# 4                          0.32                3.64
# 5                          0.28                3.61
# 6                          0.23                3.43
# 7                          0.18                3.29
# 8                          0.27                3.54
# 9                          0.33                3.68
#
#    SVM RNA-class probability                                       File
# 0                   0.998524  neg_sample_MULTIPERM_di_output_70_754.txt
# 1                   0.998834  neg_sample_MULTIPERM_di_output_26_529.txt
# 2                   0.998762  neg_sample_MULTIPERM_di_output_26_917.txt
# 3                   0.998647  neg_sample_MULTIPERM_di_output_27_914.txt
# 4                   0.999101  neg_sample_MULTIPERM_di_output_59_636.txt
# 5                   0.999041  neg_sample_MULTIPERM_di_output_25_533.txt
# 6                   0.998637  neg_sample_MULTIPERM_di_output_18_951.txt
# 7                   0.998234   neg_sample_MULTIPERM_di_output_1_640.txt
# 8                   0.998904  neg_sample_MULTIPERM_di_output_53_982.txt
# 9                   0.999155  neg_sample_MULTIPERM_di_output_43_201.txt

# %%
new_df_multiperm_di[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy    G+C content  \
# count           100000.000000    100000.000000  100000.000000
# mean                87.445100         0.361246       0.488293
# std                  0.753061         0.017875       0.026621
# min                 84.960000         0.326170       0.421830
# 25%                 86.980000         0.348790       0.469832
# 50%                 87.505000         0.360565       0.487960
# 75%                 87.977500         0.372213       0.507380
# max                 88.900000         0.419530       0.546100
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count             100000.000000  100000.000000        100000.000000
# mean                -128.353818     -29.847004           -28.456351
# std                    9.076811       7.111519             6.973738
# min                 -161.640000     -59.860000           -58.470000
# 25%                 -134.550000     -34.830000           -33.330000
# 50%                 -128.460000     -29.590000           -28.180000
# 75%                 -122.120000     -24.530000           -23.250000
# max                  -99.900000      -6.890000            -6.270000
#
#        Covariance contribution  Combinations/Pair   Mean z-score  \
# count            100000.000000      100000.000000  100000.000000
# mean                 -1.390638           2.086059     -33.886575
# std                   0.525951           0.076498       4.548805
# min                  -3.850000           1.710000     -56.680000
# 25%                  -1.710000           2.040000     -35.700000
# 50%                  -1.380000           2.090000     -32.830000
# 75%                  -1.080000           2.140000     -30.760000
# max                   3.520000           2.450000     -23.960000
#
#        Structure conservation index  SVM decision value  \
# count                 100000.000000       100000.000000
# mean                       0.231205            3.423296
# std                        0.047103            0.148129
# min                        0.060000            2.690000
# 25%                        0.200000            3.320000
# 50%                        0.230000            3.440000
# 75%                        0.260000            3.530000
# max                        0.450000            3.750000
#
#        SVM RNA-class probability
# count              100000.000000
# mean                    0.998563
# std                     0.000446
# min                     0.994327
# 25%                     0.998327
# 50%                     0.998658
# 75%                     0.998888
# max                     0.999261

# %%
new_df_aln_shuffle = df_aln_shuffle.drop(['Sequences', 'Columns', 'File'], axis=1)
new_df_aln_shuffle.head(10)
# Out:
#    Mean pairwise identity  Shannon entropy  G+C content  \
# 0                   87.61          0.35554      0.50441
# 1                   87.24          0.36982      0.47497
# 2                   87.49          0.36246      0.48715
# 3                   86.21          0.39250      0.45582
# 4                   87.36          0.36696      0.46256
# 5                   86.00          0.39443      0.46835
# 6                   88.73          0.32721      0.48063
# 7                   87.03          0.37237      0.47679
# 8                   88.20          0.34545      0.47778
# 9                   88.03          0.34795      0.44066
#
#    Mean single sequence MFE  Consensus MFE  Energy contribution  \
# 0                   -138.94         -66.62               -63.02
# 1                   -131.83         -38.87               -35.94
# 2                   -140.74         -49.14               -47.12
# 3                   -129.61         -33.70               -31.22
# 4                   -119.30         -45.16               -43.23
# 5                   -116.31         -27.79               -26.55
# 6                   -130.92         -59.13               -56.20
# 7                   -125.94         -39.90               -37.14
# 8                   -127.93         -53.23               -49.06
# 9                   -117.69         -37.64               -35.07
#
#    Covariance contribution  Combinations/Pair  Mean z-score  \
# 0                    -3.61               2.23        -33.19
# 1                    -2.92               2.37        -37.27
# 2                    -2.02               2.32        -39.48
# 3                    -2.49               2.38        -49.15
# 4                    -1.93               2.34        -37.31
# 5                    -1.25               2.28        -32.16
# 6                    -2.94               2.21        -35.50
# 7                    -2.76               2.31        -35.01
# 8                    -4.18               2.49        -34.50
# 9                    -2.57               2.45        -46.24
#
#    Structure conservation index  SVM decision value  SVM RNA-class probability
# 0                          0.48                3.65                   0.999110
# 1                          0.29                3.62                   0.999063
# 2                          0.35                3.71                   0.999208
# 3                          0.26                3.58                   0.998988
# 4                          0.38                3.74                   0.999246
# 5                          0.24                3.53                   0.998872
# 6                          0.45                3.67                   0.999142
# 7                          0.32                3.68                   0.999168
# 8                          0.42                3.71                   0.999207
# 9                          0.32                3.65                   0.999111

# %%
new_df_aln_shuffle[['Mean pairwise identity',
        'Shannon entropy','G+C content',
        'Mean single sequence MFE',	
        'Consensus MFE','Energy contribution',
        'Covariance contribution',
        'Combinations/Pair',
        'Mean z-score',
        'Structure conservation index',
        'SVM decision value',
        'SVM RNA-class probability']].describe()
# Out:
#        Mean pairwise identity  Shannon entropy    G+C content  \
# count           100000.000000    100000.000000  100000.000000
# mean                87.445100         0.361246       0.488293
# std                  0.753061         0.017875       0.026621
# min                 84.960000         0.326170       0.421830
# 25%                 86.980000         0.348790       0.469832
# 50%                 87.505000         0.360565       0.487960
# 75%                 87.977500         0.372213       0.507380
# max                 88.900000         0.419530       0.546100
#
#        Mean single sequence MFE  Consensus MFE  Energy contribution  \
# count             100000.000000  100000.000000        100000.000000
# mean                -135.647423     -52.265821           -49.185115
# std                    9.944092      10.520514            10.105872
# min                 -171.950000     -94.850000           -90.580000
# 25%                 -142.572500     -59.380000           -56.010000
# 50%                 -135.950000     -51.950000           -48.850000
# 75%                 -128.790000     -44.760000           -41.950000
# max                 -104.530000     -18.790000           -17.560000
#
#        Covariance contribution  Combinations/Pair   Mean z-score  \
# count            100000.000000      100000.000000  100000.000000
# mean                 -3.080733           2.319713     -37.885609
# std                   0.994986           0.113290       5.195674
# min                  -7.190000           1.810000     -62.130000
# 25%                  -3.700000           2.250000     -40.140000
# 50%                  -3.030000           2.320000     -36.760000
# 75%                  -2.410000           2.390000     -34.260000
# max                   1.810000           2.740000     -25.010000
#
#        Structure conservation index  SVM decision value  \
# count                 100000.000000       100000.000000
# mean                       0.383664            3.687537
# std                        0.062894            0.062868
# min                        0.140000            3.100000
# 25%                        0.340000            3.670000
# 50%                        0.380000            3.700000
# 75%                        0.430000            3.730000
# max                        0.630000            3.800000
#
#        SVM RNA-class probability
# count              100000.000000
# mean                    0.999166
# std                     0.000118
# min                     0.997417
# 25%                     0.999143
# 50%                     0.999198
# 75%                     0.999232
# max                     0.999329

# %% [markdown]
# ## SVM RNA-class probability

# %%
dataframes = [new_df_sissi, new_df_sissiz_mono, new_df_sissiz_di, new_df_multiperm_mono, new_df_multiperm_di, new_df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['SVM RNA-class probability'] for df in dataframes]
thresholds = [0.9]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1)

plt.axvspan(0.5, 1.5, color="darkgray", alpha=0.75, edgecolor="black", label='Positive Samples')
plt.axvspan(1.5, 3.5, color="sandybrown", alpha=0.75, edgecolor="black", label='Simulation')
plt.axvspan(3.5, 6.5, color="mediumpurple", alpha=0.75, edgecolor="black", label='Shuffle')

plt.ylim(0.985, 1.0)
plt.title('Boxplot SVM RNA-class probability')
plt.legend()
plt.show()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\803804746.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\803804746.py:12: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(0.5, 1.5, color="darkgray", alpha=0.75, edgecolor="black", label='Positive Samples')
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\803804746.py:13: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(1.5, 3.5, color="sandybrown", alpha=0.75, edgecolor="black", label='Simulation')
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\803804746.py:14: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(3.5, 6.5, color="mediumpurple", alpha=0.75, edgecolor="black", label='Shuffle')

# %% [markdown]
# ## Structure conservation index (SCI)

# %%
dataframes = [new_df_sissi, new_df_sissiz_mono, new_df_sissiz_di, new_df_multiperm_mono, new_df_multiperm_di, new_df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Structure conservation index'] for df in dataframes]
thresholds = [0.5, 0.75]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Structure conservation index (SCI)')
plt.show()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\1882094440.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Mean z-score

# %%
dataframes = [new_df_sissi, new_df_sissiz_mono, new_df_sissiz_di, new_df_multiperm_mono, new_df_multiperm_di, new_df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Mean z-score'] for df in dataframes]
thresholds = [-4, 4]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Mean z-score')
plt.show()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\1086545868.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Consensus MFE

# %%
dataframes = [new_df_sissi, new_df_sissiz_mono, new_df_sissiz_di, new_df_multiperm_mono, new_df_multiperm_di, new_df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Consensus MFE'] for df in dataframes]
thresholds = [-20]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Consensus MFE')
plt.show()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\2230145245.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Mean pairwise identity

# %%
dataframes = [new_df_sissi, new_df_sissiz_mono, new_df_sissiz_di, new_df_multiperm_mono, new_df_multiperm_di, new_df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Mean pairwise identity'] for df in dataframes]
thresholds = [40, 60, 90]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.ylim(40, 100)
plt.title('Boxplot Mean pairwise identity')
plt.show()
# Out:
# C:\Users\Stefan\AppData\Local\Temp\ipykernel_19716\1678256478.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Confusion Matrix and Roc-Curve

# %%
def confusionMatrixAndRocCurve(data):
    threshold = -3
    data_X = data.drop(columns=["z-score calculated from 7. 8. and 9.", "File"])
    data_y = (data['z-score calculated from 7. 8. and 9.'] > threshold).astype(int)

    X_train, X_test, y_train, y_test = train_test_split(data_X, data_y , test_size=0.3, random_state=42)

    model = LogisticRegression() 
    model.fit(X_train, y_train) 
    y_pred_proba = model.predict_proba(X_test)[:, 1] 
    y_pred = (y_pred_proba >= 0.5).astype(int)

    accuracy = accuracy_score(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)

    print(accuracy)
    print(class_report)
    
    conf_matrix = metrics.confusion_matrix(y_test, y_pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = [0, 1])

    cm_display.plot()
    plt.show() 

    fpr, tpr, thresholds = roc_curve(y_test, y_pred) 

    print(fpr)
    print(tpr)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    plt.figure()  
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve for ...')
    plt.legend()
    plt.show()
