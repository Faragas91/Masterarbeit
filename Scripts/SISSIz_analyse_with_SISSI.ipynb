# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, auc, accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import metrics

# %%
# df_sissi = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/sissi.xlsx"))
# df_sissiz_mono = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/sissiz_mono.xlsx"))
# df_sissiz_di = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/sissiz_di.xlsx"))
# df_multiperm_mono = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/multiperm_mono.xlsx"))
# df_multiperm_di = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/multiperm_di.xlsx"))
# df_aln_shuffle = pd.DataFrame(pd.read_excel("D:/Masterarbeit_Daten/Data/SISSIz_Data_di_Excel/alifoldz.xlsx"))

# %%
df_sissi = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/sissi.xlsx"))
df_sissiz_mono = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/sissiz_mono.xlsx"))
df_sissiz_di = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/sissiz_di.xlsx"))
df_multiperm_mono = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/multiperm_mono.xlsx"))
df_multiperm_di = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/multiperm_di.xlsx"))
df_aln_shuffle = pd.DataFrame(pd.read_excel("C:/bla/Waste/MA/Data/SISSIz_Data_di_Excel/alifoldz.xlsx"))

# %%
df_sissi.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8856
# 1                                             0.8703
# 2                                             0.8815
# 3                                             0.8853
# 4                                             0.8863
# 5                                             0.8780
# 6                                             0.8754
# 7                                             0.8590
# 8                                             0.8778
# 9                                             0.8820
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8770
# 1                                  0.8596
# 2                                  0.8738
# 3                                  0.8774
# 4                                  0.8779
# 5                                  0.8687
# 6                                  0.8653
# 7                                  0.8483
# 8                                  0.8701
# 9                                  0.8742
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0042
# 1                                             0.0042
# 2                                             0.0037
# 3                                             0.0039
# 4                                             0.0041
# 5                                             0.0046
# 6                                             0.0052
# 7                                             0.0047
# 8                                             0.0046
# 9                                             0.0047
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.6048      0.4930
# 1                               0.6407      0.4768
# 2                               0.6319      0.5034
# 3                               0.5775      0.4584
# 4                               0.6734      0.5127
# 5                               0.6482      0.4950
# 6                               0.5838      0.4691
# 7                               0.5576      0.4777
# 8                               0.6170      0.4477
# 9                               0.7268      0.4778
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                             -91.01
# 1                                             -85.20
# 2                                            -102.79
# 3                                             -76.68
# 4                                            -105.91
# 5                                             -95.02
# 6                                             -84.46
# 7                                             -81.20
# 8                                             -81.04
# 9                                            -106.38
#
#    Average consensus MFE in the sampled alignments  \
# 0                                            -8.12
# 1                                            -3.54
# 2                                            -5.98
# 3                                            -6.24
# 4                                            -9.52
# 5                                            -7.14
# 6                                            -4.49
# 7                                            -3.33
# 8                                            -4.43
# 9                                            -6.48
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               4.73
# 1                                               2.45
# 2                                               3.44
# 3                                               3.30
# 4                                               4.44
# 5                                               4.00
# 6                                               3.16
# 7                                               3.10
# 8                                               3.18
# 9                                               3.66
#
#    z-score calculated from 7. 8. and 9.                      File
# 0                                -17.54  pos_sample_output_55.txt
# 1                                -33.39  pos_sample_output_89.txt
# 2                                -28.15  pos_sample_output_72.txt
# 3                                -21.36  pos_sample_output_20.txt
# 4                                -21.70  pos_sample_output_97.txt
# 5                                -21.97  pos_sample_output_37.txt
# 6                                -25.27  pos_sample_output_87.txt
# 7                                -25.11  pos_sample_output_12.txt
# 8                                -24.12  pos_sample_output_68.txt
# 9                                -27.28  pos_sample_output_11.txt

# %%
df_sissi[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                         100.000000
# mean                                            0.874451
# std                                             0.007569
# min                                             0.849600
# 25%                                             0.869800
# 50%                                             0.875050
# 75%                                             0.879775
# max                                             0.889000
#
#        Average MPI of the sampled alignments.  \
# count                              100.000000
# mean                                 0.864875
# std                                  0.007920
# min                                  0.840100
# 25%                                  0.859975
# 50%                                  0.865300
# 75%                                  0.870700
# max                                  0.880800
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                         100.000000
# mean                                            0.004591
# std                                             0.000391
# min                                             0.003700
# 25%                                             0.004300
# 50%                                             0.004600
# 75%                                             0.004900
# max                                             0.005500
#
#        Structural Conservation Index (SCI)  GC-Content  \
# count                           100.000000  100.000000
# mean                              0.585270    0.488291
# std                               0.070697    0.026756
# min                               0.414100    0.421800
# 25%                               0.535175    0.469850
# 50%                               0.584350    0.488000
# 75%                               0.631675    0.507400
# max                               0.792000    0.546100
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                         100.000000
# mean                                          -85.926300
# std                                            12.788426
# min                                          -128.040000
# 25%                                           -93.505000
# 50%                                           -85.280000
# 75%                                           -76.972500
# max                                           -56.460000
#
#        Average consensus MFE in the sampled alignments  \
# count                                        100.00000
# mean                                          -5.88540
# std                                            1.62772
# min                                          -13.21000
# 25%                                           -6.89500
# 50%                                           -5.82500
# 75%                                           -4.61250
# max                                           -2.90000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                         100.000000
# mean                                            3.446100
# std                                             0.501599
# min                                             2.280000
# 25%                                             3.122500
# 50%                                             3.385000
# 75%                                             3.820000
# max                                             5.190000
#
#        z-score calculated from 7. 8. and 9.
# count                            100.000000
# mean                             -23.610500
# std                                4.473365
# min                              -35.900000
# 25%                              -26.117500
# 50%                              -23.315000
# 75%                              -20.842500
# max                              -13.940000

# %%
df_sissiz_mono.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8736
# 1                                             0.8792
# 2                                             0.8691
# 3                                             0.8413
# 4                                             0.8683
# 5                                             0.8649
# 6                                             0.8629
# 7                                             0.8746
# 8                                             0.8696
# 9                                             0.8533
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8628
# 1                                  0.8697
# 2                                  0.8580
# 3                                  0.8301
# 4                                  0.8576
# 5                                  0.8532
# 6                                  0.8528
# 7                                  0.8646
# 8                                  0.8581
# 9                                  0.8416
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0034
# 1                                             0.0038
# 2                                             0.0042
# 3                                             0.0047
# 4                                             0.0036
# 5                                             0.0043
# 6                                             0.0037
# 7                                             0.0042
# 8                                             0.0043
# 9                                             0.0051
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.0577      0.5127
# 1                               0.0079      0.4329
# 2                               0.0558      0.4767
# 3                               0.0415      0.5297
# 4                               0.0015      0.4590
# 5                               0.0870      0.5411
# 6                               0.0120      0.4624
# 7                               0.0865      0.4813
# 8                               0.0276      0.4921
# 9                               0.0412      0.4714
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                              -7.27
# 1                                              -0.77
# 2                                              -5.83
# 3                                              -5.45
# 4                                              -0.17
# 5                                             -11.36
# 6                                              -1.29
# 7                                              -9.51
# 8                                              -3.34
# 9                                              -3.83
#
#    Average consensus MFE in the sampled alignments  \
# 0                                            -9.87
# 1                                            -5.06
# 2                                            -5.85
# 3                                            -5.54
# 4                                            -6.27
# 5                                            -9.52
# 6                                            -6.49
# 7                                            -8.94
# 8                                            -8.23
# 9                                            -3.92
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               4.02
# 1                                               3.49
# 2                                               3.75
# 3                                               3.38
# 4                                               3.62
# 5                                               4.38
# 6                                               3.36
# 7                                               3.34
# 8                                               3.97
# 9                                               2.86
#
#    z-score calculated from 7. 8. and 9.  \
# 0                                  0.65
# 1                                  1.23
# 2                                  0.00
# 3                                  0.03
# 4                                  1.69
# 5                                 -0.42
# 6                                  1.55
# 7                                 -0.17
# 8                                  1.23
# 9                                  0.03
#
#                                        File
# 0  neg_sample_SISSIz_mono_output_60_175.txt
# 1  neg_sample_SISSIz_mono_output_20_322.txt
# 2  neg_sample_SISSIz_mono_output_88_522.txt
# 3  neg_sample_SISSIz_mono_output_23_838.txt
# 4  neg_sample_SISSIz_mono_output_62_322.txt
# 5  neg_sample_SISSIz_mono_output_65_491.txt
# 6  neg_sample_SISSIz_mono_output_38_840.txt
# 7  neg_sample_SISSIz_mono_output_33_485.txt
# 8  neg_sample_SISSIz_mono_output_16_182.txt
# 9  neg_sample_SISSIz_mono_output_47_686.txt

# %%
df_sissiz_mono[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()


# Example neg_sample_SISSIz_mono_output_60_175.txt
# z-score = (RNAalifold consensus Minimum Free Energy (MFE) of the original alignment - Average consensus MFE in the sampled alignments) / Standard deviation of the consensus MFE in the sampled alignments
# z-score = (-7.27 - -9.87) / 4.02 = 0,65
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                      100000.000000
# mean                                            0.865836
# std                                             0.009047
# min                                             0.827600
# 25%                                             0.859900
# 50%                                             0.866300
# 75%                                             0.872200
# max                                             0.892600
#
#        Average MPI of the sampled alignments.  \
# count                           100000.000000
# mean                                 0.855446
# std                                  0.009256
# min                                  0.816400
# 25%                                  0.849300
# 50%                                  0.855900
# 75%                                  0.862000
# max                                  0.884400
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                      100000.000000
# mean                                            0.004228
# std                                             0.000388
# min                                             0.002700
# 25%                                             0.004000
# 50%                                             0.004200
# 75%                                             0.004500
# max                                             0.006000
#
#        Structural Conservation Index (SCI)     GC-Content  \
# count                        100000.000000  100000.000000
# mean                              0.039971       0.488262
# std                               0.027651       0.035076
# min                              -0.000000       0.350300
# 25%                               0.018600       0.464700
# 50%                               0.036400       0.488900
# 75%                               0.056900       0.512100
# max                               0.176400       0.611800
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                      100000.000000
# mean                                           -4.689540
# std                                             3.409589
# min                                           -22.830000
# 25%                                            -6.700000
# 50%                                            -4.150000
# 75%                                            -2.070000
# max                                             0.000000
#
#        Average consensus MFE in the sampled alignments  \
# count                                    100000.000000
# mean                                         -7.278781
# std                                           2.123409
# min                                         -17.800000
# 25%                                          -8.660000
# 50%                                          -7.140000
# 75%                                          -5.730000
# max                                          -1.690000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                      100000.000000
# mean                                            3.637573
# std                                             0.539155
# min                                             1.740000
# 25%                                             3.270000
# 50%                                             3.630000
# 75%                                             4.000000
# max                                             5.970000
#
#        z-score calculated from 7. 8. and 9.
# count                         100000.000000
# mean                               0.719268
# std                                0.759088
# min                               -3.890000
# 25%                                0.260000
# 50%                                0.830000
# 75%                                1.280000
# max                                2.860000

# %%
df_sissiz_di.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8685
# 1                                             0.8805
# 2                                             0.8493
# 3                                             0.8667
# 4                                             0.8711
# 5                                             0.8611
# 6                                             0.8703
# 7                                             0.8512
# 8                                             0.8572
# 9                                             0.8576
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8569
# 1                                  0.8699
# 2                                  0.8382
# 3                                  0.8554
# 4                                  0.8612
# 5                                  0.8526
# 6                                  0.8612
# 7                                  0.8410
# 8                                  0.8463
# 9                                  0.8477
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0044
# 1                                             0.0039
# 2                                             0.0041
# 3                                             0.0043
# 4                                             0.0042
# 5                                             0.0036
# 6                                             0.0036
# 7                                             0.0050
# 8                                             0.0043
# 9                                             0.0043
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.0786      0.4970
# 1                               0.0434      0.5350
# 2                               0.0365      0.4919
# 3                               0.0096      0.4767
# 4                               0.0597      0.5329
# 5                               0.0770      0.4825
# 6                               0.1082      0.5236
# 7                               0.0230      0.4382
# 8                               0.0894      0.4659
# 9                               0.0139      0.4876
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                              -9.66
# 1                                              -5.74
# 2                                              -4.39
# 3                                              -1.01
# 4                                              -7.73
# 5                                              -8.63
# 6                                             -14.59
# 7                                              -2.42
# 8                                              -9.99
# 9                                              -1.63
#
#    Average consensus MFE in the sampled alignments  \
# 0                                           -10.22
# 1                                           -12.09
# 2                                            -5.12
# 3                                            -7.90
# 4                                           -11.36
# 5                                            -6.44
# 6                                            -9.56
# 7                                            -4.36
# 8                                            -5.28
# 9                                            -5.41
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               4.67
# 1                                               4.88
# 2                                               3.16
# 3                                               4.32
# 4                                               4.29
# 5                                               3.28
# 6                                               4.35
# 7                                               2.43
# 8                                               3.26
# 9                                               3.28
#
#    z-score calculated from 7. 8. and 9.  \
# 0                                  0.12
# 1                                  1.30
# 2                                  0.23
# 3                                  1.60
# 4                                  0.85
# 5                                 -0.67
# 6                                 -1.16
# 7                                  0.80
# 8                                 -1.44
# 9                                  1.15
#
#                                      File
# 0   neg_sample_SISSIz_di_output_7_471.txt
# 1   neg_sample_SISSIz_di_output_69_45.txt
# 2  neg_sample_SISSIz_di_output_76_235.txt
# 3  neg_sample_SISSIz_di_output_48_902.txt
# 4   neg_sample_SISSIz_di_output_9_815.txt
# 5  neg_sample_SISSIz_di_output_29_568.txt
# 6  neg_sample_SISSIz_di_output_91_913.txt
# 7   neg_sample_SISSIz_di_output_1_229.txt
# 8  neg_sample_SISSIz_di_output_92_765.txt
# 9  neg_sample_SISSIz_di_output_73_895.txt

# %%
df_sissiz_di[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                      100000.000000
# mean                                            0.864899
# std                                             0.009094
# min                                             0.826700
# 25%                                             0.859000
# 50%                                             0.865300
# 75%                                             0.871400
# max                                             0.893700
#
#        Average MPI of the sampled alignments.  \
# count                           100000.000000
# mean                                 0.854306
# std                                  0.009258
# min                                  0.814300
# 25%                                  0.848200
# 50%                                  0.854600
# 75%                                  0.860900
# max                                  0.885500
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                      100000.000000
# mean                                            0.004242
# std                                             0.000388
# min                                             0.002700
# 25%                                             0.004000
# 50%                                             0.004200
# 75%                                             0.004500
# max                                             0.006200
#
#        Structural Conservation Index (SCI)     GC-Content  \
# count                        100000.000000  100000.000000
# mean                              0.049625       0.489272
# std                               0.030788       0.035767
# min                              -0.000000       0.354300
# 25%                               0.026700       0.465100
# 50%                               0.046100       0.489600
# 75%                               0.068300       0.513600
# max                               0.215300       0.617700
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                      100000.000000
# mean                                           -5.877318
# std                                             3.824714
# min                                           -26.960000
# 25%                                            -8.110000
# 50%                                            -5.340000
# 75%                                            -3.020000
# max                                             0.000000
#
#        Average consensus MFE in the sampled alignments  \
# count                                    100000.000000
# mean                                         -8.072087
# std                                           2.387446
# min                                         -22.030000
# 25%                                          -9.560000
# 50%                                          -7.870000
# 75%                                          -6.350000
# max                                          -1.920000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                      100000.000000
# mean                                            3.873444
# std                                             0.591971
# min                                             1.920000
# 25%                                             3.460000
# 50%                                             3.850000
# 75%                                             4.260000
# max                                             7.050000
#
#        z-score calculated from 7. 8. and 9.
# count                         100000.000000
# mean                               0.570776
# std                                0.808148
# min                               -3.960000
# 25%                                0.080000
# 50%                                0.670000
# 75%                                1.160000
# max                                2.940000

# %%
df_multiperm_mono.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8690
# 1                                             0.8496
# 2                                             0.8642
# 3                                             0.8815
# 4                                             0.8730
# 5                                             0.8765
# 6                                             0.8726
# 7                                             0.8840
# 8                                             0.8698
# 9                                             0.8698
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8602
# 1                                  0.8409
# 2                                  0.8575
# 3                                  0.8729
# 4                                  0.8631
# 5                                  0.8665
# 6                                  0.8625
# 7                                  0.8760
# 8                                  0.8593
# 9                                  0.8591
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0049
# 1                                             0.0049
# 2                                             0.0050
# 3                                             0.0046
# 4                                             0.0044
# 5                                             0.0045
# 6                                             0.0046
# 7                                             0.0043
# 8                                             0.0047
# 9                                             0.0049
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.2117      0.4510
# 1                               0.1893      0.5181
# 2                               0.1777      0.5000
# 3                               0.2782      0.5034
# 4                               0.2223      0.4685
# 5                               0.1637      0.4869
# 6                               0.1959      0.5025
# 7                               0.1405      0.4567
# 8                               0.2395      0.5077
# 9                               0.2215      0.5077
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                             -22.67
# 1                                             -24.54
# 2                                             -21.70
# 3                                             -34.47
# 4                                             -24.16
# 5                                             -18.11
# 6                                             -24.84
# 7                                             -15.80
# 8                                             -29.05
# 9                                             -28.08
#
#    Average consensus MFE in the sampled alignments  \
# 0                                            -4.22
# 1                                            -3.82
# 2                                            -4.54
# 3                                            -5.84
# 4                                            -3.73
# 5                                            -4.47
# 6                                            -6.33
# 7                                            -5.39
# 8                                            -6.57
# 9                                            -5.60
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               3.37
# 1                                               2.82
# 2                                               2.86
# 3                                               3.04
# 4                                               2.64
# 5                                               3.06
# 6                                               3.77
# 7                                               3.34
# 8                                               4.11
# 9                                               3.47
#
#    z-score calculated from 7. 8. and 9.  \
# 0                                 -5.48
# 1                                 -7.34
# 2                                 -5.99
# 3                                 -9.41
# 4                                 -7.75
# 5                                 -4.46
# 6                                 -4.92
# 7                                 -3.11
# 8                                 -5.47
# 9                                 -6.47
#
#                                           File
# 0  neg_sample_MULTIPERM_mono_output_39_770.txt
# 1  neg_sample_MULTIPERM_mono_output_23_824.txt
# 2   neg_sample_MULTIPERM_mono_output_2_971.txt
# 3   neg_sample_MULTIPERM_mono_output_72_12.txt
# 4  neg_sample_MULTIPERM_mono_output_29_441.txt
# 5  neg_sample_MULTIPERM_mono_output_34_847.txt
# 6   neg_sample_MULTIPERM_mono_output_5_384.txt
# 7  neg_sample_MULTIPERM_mono_output_58_446.txt
# 8  neg_sample_MULTIPERM_mono_output_41_976.txt
# 9  neg_sample_MULTIPERM_mono_output_41_304.txt

# %%
df_multiperm_mono[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                      100000.000000
# mean                                            0.874451
# std                                             0.007531
# min                                             0.849600
# 25%                                             0.869800
# 50%                                             0.875050
# 75%                                             0.879775
# max                                             0.889000
#
#        Average MPI of the sampled alignments.  \
# count                           100000.000000
# mean                                 0.864934
# std                                  0.007888
# min                                  0.837600
# 25%                                  0.859600
# 50%                                  0.865500
# 75%                                  0.870400
# max                                  0.882600
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                      100000.000000
# mean                                            0.004538
# std                                             0.000393
# min                                             0.003000
# 25%                                             0.004300
# 50%                                             0.004500
# 75%                                             0.004800
# max                                             0.006500
#
#        Structural Conservation Index (SCI)     GC-Content  \
# count                        100000.000000  100000.000000
# mean                              0.194130       0.488291
# std                               0.050483       0.026622
# min                               0.023500       0.421800
# 25%                               0.158500       0.469850
# 50%                               0.192000       0.488000
# 75%                               0.227800       0.507400
# max                               0.422500       0.546100
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                      100000.000000
# mean                                          -22.883175
# std                                             6.797357
# min                                           -53.950000
# 25%                                           -27.510000
# 50%                                           -22.510000
# 75%                                           -17.890000
# max                                            -2.640000
#
#        Average consensus MFE in the sampled alignments  \
# count                                    100000.000000
# mean                                         -5.462562
# std                                           1.477084
# min                                         -14.360000
# 25%                                          -6.380000
# 50%                                          -5.390000
# 75%                                          -4.370000
# max                                          -1.640000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                      100000.000000
# mean                                            3.301855
# std                                             0.481819
# min                                             1.580000
# 25%                                             2.970000
# 50%                                             3.290000
# 75%                                             3.620000
# max                                             5.910000
#
#        z-score calculated from 7. 8. and 9.
# count                         100000.000000
# mean                              -5.303137
# std                                1.802749
# min                              -16.640000
# 25%                               -6.440000
# 50%                               -5.170000
# 75%                               -4.030000
# max                                0.520000

# %%
df_multiperm_di.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8797
# 1                                             0.8723
# 2                                             0.8723
# 3                                             0.8759
# 4                                             0.8805
# 5                                             0.8656
# 6                                             0.8768
# 7                                             0.8630
# 8                                             0.8782
# 9                                             0.8761
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8705
# 1                                  0.8630
# 2                                  0.8604
# 3                                  0.8662
# 4                                  0.8694
# 5                                  0.8536
# 6                                  0.8665
# 7                                  0.8516
# 8                                  0.8681
# 9                                  0.8667
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0049
# 1                                             0.0046
# 2                                             0.0056
# 3                                             0.0045
# 4                                             0.0047
# 5                                             0.0049
# 6                                             0.0045
# 7                                             0.0049
# 8                                             0.0045
# 9                                             0.0044
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.1569      0.4680
# 1                               0.2510      0.4925
# 2                               0.1924      0.4925
# 3                               0.1879      0.4941
# 4                               0.2850      0.4889
# 5                               0.2053      0.5192
# 6                               0.1581      0.4699
# 7                               0.1391      0.4328
# 8                               0.2211      0.5130
# 9                               0.3497      0.5044
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                             -16.60
# 1                                             -30.27
# 2                                             -23.27
# 3                                             -22.56
# 4                                             -33.13
# 5                                             -25.78
# 6                                             -18.23
# 7                                             -14.35
# 8                                             -27.94
# 9                                             -42.99
#
#    Average consensus MFE in the sampled alignments  \
# 0                                            -4.54
# 1                                            -5.88
# 2                                            -5.44
# 3                                            -6.34
# 4                                            -9.54
# 5                                            -4.97
# 6                                            -6.45
# 7                                            -4.16
# 8                                            -5.22
# 9                                            -5.62
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               3.12
# 1                                               3.46
# 2                                               3.53
# 3                                               3.45
# 4                                               4.59
# 5                                               3.03
# 6                                               3.58
# 7                                               2.78
# 8                                               3.45
# 9                                               3.81
#
#    z-score calculated from 7. 8. and 9.  \
# 0                                 -3.87
# 1                                 -7.06
# 2                                 -5.05
# 3                                 -4.71
# 4                                 -5.14
# 5                                 -6.88
# 6                                 -3.29
# 7                                 -3.66
# 8                                 -6.58
# 9                                 -9.81
#
#                                         File
# 0  neg_sample_MULTIPERM_di_output_70_754.txt
# 1  neg_sample_MULTIPERM_di_output_26_529.txt
# 2  neg_sample_MULTIPERM_di_output_26_917.txt
# 3  neg_sample_MULTIPERM_di_output_27_914.txt
# 4  neg_sample_MULTIPERM_di_output_59_636.txt
# 5  neg_sample_MULTIPERM_di_output_25_533.txt
# 6  neg_sample_MULTIPERM_di_output_18_951.txt
# 7   neg_sample_MULTIPERM_di_output_1_640.txt
# 8  neg_sample_MULTIPERM_di_output_53_982.txt
# 9  neg_sample_MULTIPERM_di_output_43_201.txt

# %%
df_multiperm_di[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                      100000.000000
# mean                                            0.874451
# std                                             0.007531
# min                                             0.849600
# 25%                                             0.869800
# 50%                                             0.875050
# 75%                                             0.879775
# max                                             0.889000
#
#        Average MPI of the sampled alignments.  \
# count                           100000.000000
# mean                                 0.864959
# std                                  0.007866
# min                                  0.837800
# 25%                                  0.859700
# 50%                                  0.865500
# 75%                                  0.870400
# max                                  0.883300
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                      100000.000000
# mean                                            0.004536
# std                                             0.000391
# min                                             0.003100
# 25%                                             0.004300
# 50%                                             0.004500
# 75%                                             0.004800
# max                                             0.006400
#
#        Structural Conservation Index (SCI)     GC-Content  \
# count                        100000.000000  100000.000000
# mean                              0.193141       0.488291
# std                               0.051292       0.026622
# min                               0.024900       0.421800
# 25%                               0.156400       0.469850
# 50%                               0.191000       0.488000
# 75%                               0.227700       0.507400
# max                               0.425000       0.546100
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                      100000.000000
# mean                                          -22.755578
# std                                             6.877533
# min                                           -54.910000
# 25%                                           -27.470000
# 50%                                           -22.400000
# 75%                                           -17.670000
# max                                            -2.710000
#
#        Average consensus MFE in the sampled alignments  \
# count                                    100000.000000
# mean                                         -5.621597
# std                                           1.538601
# min                                         -14.640000
# 25%                                          -6.560000
# 50%                                          -5.530000
# 75%                                          -4.500000
# max                                          -1.480000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                      100000.000000
# mean                                            3.341209
# std                                             0.497537
# min                                             1.550000
# 25%                                             3.000000
# 50%                                             3.330000
# 75%                                             3.660000
# max                                             5.710000
#
#        z-score calculated from 7. 8. and 9.
# count                         100000.000000
# mean                              -5.153545
# std                                1.781275
# min                              -14.560000
# 25%                               -6.280000
# 50%                               -5.030000
# 75%                               -3.890000
# max                                0.200000

# %%
df_aln_shuffle.head(10)
# Out:
#    Mean Pairwise Identity (MPI) of the input alignment  \
# 0                                             0.8761
# 1                                             0.8724
# 2                                             0.8749
# 3                                             0.8621
# 4                                             0.8736
# 5                                             0.8600
# 6                                             0.8873
# 7                                             0.8703
# 8                                             0.8820
# 9                                             0.8803
#
#    Average MPI of the sampled alignments.  \
# 0                                  0.8679
# 1                                  0.8624
# 2                                  0.8655
# 3                                  0.8526
# 4                                  0.8628
# 5                                  0.8501
# 6                                  0.8770
# 7                                  0.8601
# 8                                  0.8743
# 9                                  0.8699
#
#    Standard deviation of the MPIs of the sampled alignments  \
# 0                                             0.0046
# 1                                             0.0046
# 2                                             0.0051
# 3                                             0.0044
# 4                                             0.0040
# 5                                             0.0049
# 6                                             0.0041
# 7                                             0.0044
# 8                                             0.0049
# 9                                             0.0051
#
#    Structural Conservation Index (SCI)  GC-Content  \
# 0                               0.4862      0.5044
# 1                               0.2680      0.4750
# 2                               0.3376      0.4871
# 3                               0.2573      0.4558
# 4                               0.3739      0.4626
# 5                               0.1840      0.4683
# 6                               0.4605      0.4806
# 7                               0.3363      0.4768
# 8                               0.4254      0.4778
# 9                               0.3027      0.4407
#
#    RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# 0                                             -62.40
# 1                                             -31.79
# 2                                             -44.11
# 3                                             -30.75
# 4                                             -40.54
# 5                                             -19.20
# 6                                             -54.32
# 7                                             -38.33
# 8                                             -49.74
# 9                                             -32.42
#
#    Average consensus MFE in the sampled alignments  \
# 0                                            -6.69
# 1                                            -3.60
# 2                                            -5.92
# 3                                            -3.57
# 4                                            -4.73
# 5                                            -3.24
# 6                                            -7.19
# 7                                            -3.87
# 8                                            -6.15
# 9                                            -4.77
#
#    Standard deviation of the consensus MFE in the sampled alignments  \
# 0                                               3.56
# 1                                               2.56
# 2                                               3.86
# 3                                               2.41
# 4                                               3.29
# 5                                               2.78
# 6                                               3.56
# 7                                               3.36
# 8                                               3.53
# 9                                               2.92
#
#    z-score calculated from 7. 8. and 9.                                   File
# 0                                -15.64  neg_sample_ALIFOLDz_output_43_632.txt
# 1                                -11.03  neg_sample_ALIFOLDz_output_61_430.txt
# 2                                 -9.90  neg_sample_ALIFOLDz_output_77_672.txt
# 3                                -11.28  neg_sample_ALIFOLDz_output_14_650.txt
# 4                                -10.88  neg_sample_ALIFOLDz_output_32_586.txt
# 5                                 -5.73  neg_sample_ALIFOLDz_output_31_744.txt
# 6                                -13.23  neg_sample_ALIFOLDz_output_94_868.txt
# 7                                -10.24   neg_sample_ALIFOLDz_output_89_17.txt
# 8                                -12.34  neg_sample_ALIFOLDz_output_11_444.txt
# 9                                 -9.47  neg_sample_ALIFOLDz_output_21_449.txt

# %%
df_aln_shuffle[['Mean Pairwise Identity (MPI) of the input alignment',
        'Average MPI of the sampled alignments.',
        'Standard deviation of the MPIs of the sampled alignments',
        'Structural Conservation Index (SCI)',	
        'GC-Content',
        'RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.',
        'Average consensus MFE in the sampled alignments',
        'Standard deviation of the consensus MFE in the sampled alignments',
        'z-score calculated from 7. 8. and 9.']].describe()
# Out:
#        Mean Pairwise Identity (MPI) of the input alignment  \
# count                                      100000.000000
# mean                                            0.874451
# std                                             0.007531
# min                                             0.849600
# 25%                                             0.869800
# 50%                                             0.875050
# 75%                                             0.879775
# max                                             0.889000
#
#        Average MPI of the sampled alignments.  \
# count                           100000.000000
# mean                                 0.864974
# std                                  0.007891
# min                                  0.837800
# 25%                                  0.859700
# 50%                                  0.865500
# 75%                                  0.870400
# max                                  0.883000
#
#        Standard deviation of the MPIs of the sampled alignments  \
# count                                      100000.000000
# mean                                            0.004534
# std                                             0.000392
# min                                             0.003100
# 25%                                             0.004300
# 50%                                             0.004500
# 75%                                             0.004800
# max                                             0.006400
#
#        Structural Conservation Index (SCI)     GC-Content  \
# count                        100000.000000  100000.000000
# mean                              0.370919       0.488291
# std                               0.072506       0.026622
# min                               0.103400       0.421800
# 25%                               0.320800       0.469850
# 50%                               0.371400       0.488000
# 75%                               0.420600       0.507400
# max                               0.651500       0.546100
#
#        RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.  \
# count                                      100000.000000
# mean                                          -46.384955
# std                                            10.965085
# min                                           -93.190000
# 25%                                           -53.770000
# 50%                                           -46.030000
# 75%                                           -38.520000
# max                                           -11.750000
#
#        Average consensus MFE in the sampled alignments  \
# count                                    100000.000000
# mean                                         -5.618556
# std                                           1.434920
# min                                         -12.070000
# 25%                                          -6.570000
# 50%                                          -5.600000
# 75%                                          -4.530000
# max                                          -2.010000
#
#        Standard deviation of the consensus MFE in the sampled alignments  \
# count                                      100000.000000
# mean                                            3.338883
# std                                             0.473168
# min                                             1.680000
# 25%                                             3.010000
# 50%                                             3.340000
# 75%                                             3.660000
# max                                             5.300000
#
#        z-score calculated from 7. 8. and 9.
# count                         100000.000000
# mean                             -12.387286
# std                                3.457317
# min                              -36.990000
# 25%                              -14.550000
# 50%                              -12.140000
# 75%                               -9.940000
# max                               -2.070000

# %% [markdown]
# ## Mean Pairwise Identity (MPI) of the input alignment

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Mean Pairwise Identity (MPI) of the input alignment'] for df in dataframes]
thresholds = [0.40, 0.60, 0.90]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.ylim(0.0, 1.0)
plt.title('Boxplot Mean Pairwise Identity (MPI) of the input alignment')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\1437701190.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Average MPI of the sampled alignments.

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Average MPI of the sampled alignments.'] for df in dataframes]
thresholds = [0.40, 0.60, 0.90]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.ylim(0.0, 1.0)
plt.title('Boxplot Average MPI of the sampled alignments.')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\1318570128.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Standard deviation of the MPIs of the sampled alignments

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Standard deviation of the MPIs of the sampled alignments'] for df in dataframes]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.ylim(0.0, 0.01)
plt.title('Boxplot Standard deviation of the MPIs of the sampled alignments')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\4121038437.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Structural Conservation Index (SCI)

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Structural Conservation Index (SCI)'] for df in dataframes]
thresholds = [0.5, 0.75]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Structural Conservation Index (SCI)')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\1306523587.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## GC-Content

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['GC-Content'] for df in dataframes]
thresholds = [0.9]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot GC-Content')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\3074007515.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.'] for df in dataframes]
thresholds = [-20]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot RNAalifold consensus Minimum Free Energy (MFE) of the original alignment.')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\45866791.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Average consensus MFE in the sampled alignments

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Average consensus MFE in the sampled alignments'] for df in dataframes]
thresholds = [-20]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Average consensus MFE in the sampled alignments')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\2536993985.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## Standard deviation of the consensus MFE in the sampled alignments

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['Standard deviation of the consensus MFE in the sampled alignments'] for df in dataframes]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1, label=f'Threshold {t}')

plt.title('Boxplot Standard deviation of the consensus MFE in the sampled alignments')
plt.ylabel('Standard deviation of the consensus MFE in the sampled alignments')
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\3641649075.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %% [markdown]
# ## z-score

# %%
dataframes = [df_sissi, df_sissiz_mono, df_sissiz_di, df_multiperm_mono, df_multiperm_di, df_aln_shuffle]
labels = ['SISSI', 'SISSIz_mono', 'SISSIz_di', 'Multiperm_mono', 'Multiperm_di', 'aln-shuffle']
data = [df['z-score calculated from 7. 8. and 9.'] for df in dataframes]
thresholds = [-4, 4]

plt.figure(figsize=(12, 8))
plt.boxplot(data, labels=labels)

for t in thresholds:
    plt.axhline(y=t, color='red', linestyle='--', linewidth=1)

plt.axvspan(0.5, 1.5, color="darkgray", alpha=0.75, edgecolor="black", label='Positive Samples')
plt.axvspan(1.5, 3.5, color="sandybrown", alpha=0.75, edgecolor="black", label='Simulation')
plt.axvspan(3.5, 6.5, color="mediumpurple", alpha=0.75, edgecolor="black", label='Shuffle')

plt.title('Boxplot z-score ')
plt.legend()
plt.show()
# Out:
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\2957777788.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\2957777788.py:12: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(0.5, 1.5, color="darkgray", alpha=0.75, edgecolor="black", label='Positive Samples')
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\2957777788.py:13: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(1.5, 3.5, color="sandybrown", alpha=0.75, edgecolor="black", label='Simulation')
# C:\Users\stefanre\AppData\Local\Temp\ipykernel_255584\2957777788.py:14: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.axvspan(3.5, 6.5, color="mediumpurple", alpha=0.75, edgecolor="black", label='Shuffle')

# %% [markdown]
# ## TEST TRAIN SPLIT

# %%
def TrainAndTest(data):
    threshold = -3
    data_X = data.drop(columns=["z-score calculated from 7. 8. and 9.", "File"])
    data_y = (data['z-score calculated from 7. 8. and 9.'] > threshold).astype(int)

    X_train, X_test, y_train, y_test = train_test_split(data_X, data_y , test_size=0.3, random_state=42)

    model = LogisticRegression() 
    model.fit(X_train, y_train) 
    y_pred_proba = model.predict_proba(X_test)[:, 1] 
    y_pred = (y_pred_proba >= 0.5).astype(int)

    accuracy = accuracy_score(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)

    print(accuracy)
    print(class_report)

# %%
def confusionMatrix():
    conf_matrix = metrics.confusion_matrix(y_test, y_pred)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = [0, 1])

    cm_display.plot()
    plt.show()

# %%
def rocAucCurve():
    # Calculate ROC curve
    fpr, tpr, thresholds = roc_curve(y_test, y_pred) 

    print(fpr)
    print(tpr)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    plt.figure()  
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve for ...')
    plt.legend()
    plt.show()

# %%
# threshold = -3
# X_sissiz_mono = df_sissiz_mono.drop(columns=["z-score calculated from 7. 8. and 9.", "File"])
# y_sissiz_mono = (df_sissiz_mono['z-score calculated from 7. 8. and 9.'] > threshold).astype(int)

# X_train, X_test, y_train, y_test = train_test_split(X_sissiz_mono, y_sissiz_mono, test_size=0.3, random_state=42)

# model = LogisticRegression() 
# model.fit(X_train, y_train) 
# y_pred_proba = model.predict_proba(X_test)[:, 1] 
# y_pred = (y_pred_proba >= 0.5).astype(int)

# accuracy = accuracy_score(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)

# print(accuracy)
# print(class_report)
# Out:
# 0.9998666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        11
#            1       1.00      1.00      1.00     29989
#
#     accuracy                           1.00     30000
#    macro avg       1.00      0.82      0.89     30000
# weighted avg       1.00      1.00      1.00     30000

# %%
# print(y_sissiz_mono.value_counts())
# print(y_pred_proba)
# plt.hist(y_pred_proba, bins=10)
# plt.xlabel('Vorhersagewahrscheinlichkeit')
# plt.ylabel('Häufigkeit')
# plt.title('Verteilung der Vorhersagewahrscheinlichkeiten')
# plt.show()
# Out:
# z-score calculated from 7. 8. and 9.
# 1    99967
# 0       33
# Name: count, dtype: int64
# [0.99999867 1.         1.         ... 1.         0.99999986 1.        ]

# %% [markdown]
# ## CONFUSION MATRIX

# %%
conf_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = conf_matrix, display_labels = [0, 1])

cm_display.plot()
plt.show()

# %% [markdown]
# ## ROC-AUC CURVE

# %%
# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred) 

print(fpr)
print(tpr)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()  
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for ...')
plt.legend()
plt.show()
# Out:
# [0.         0.36363636 1.        ]
# [0. 1. 1.]
